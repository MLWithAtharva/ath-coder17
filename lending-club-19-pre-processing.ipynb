# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import dask.dataframe as dd
import plotly.express as px
# import  cuml
# import cudf
import xgboost
import lightgbm
import matplotlib.pyplot as plt 
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm
# Display all columns in the DataFrame
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows (use with caution for large DataFrames)
pd.set_option('display.max_colwidth', None) # Show full column width
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import missingno

# %%
data19 = pd.read_csv('/kaggle/input/lending-club-2019/2019.csv')

# %%
data19.shape
data19.head()

# %%
data19.replace('',np.nan,inplace = True)

# %%
## breakung it mom

data19['month'] = pd.to_datetime(data19['issue_d']).dt.month

# %%
data19.isnull().mean().sort_values(ascending=False) * 100

# %%
data19 = data19.loc[:,data19.isnull().mean() <0.5]
data19.shape

# %%
numeric_cols =  data19.select_dtypes(include = "number")
char_cols = data19.select_dtypes(include = "object")
date_cols = data19.select_dtypes(include = "datetime")
category_cols =   data19.select_dtypes(include = "category")

# %%
date_cols['issue_d']

# %%
data19.info()
